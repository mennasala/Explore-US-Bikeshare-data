# %%
import time
from pandas import*
from numpy import*

CITY_DATA = { 'chicago':       'E:\\Data Analysis\\projects\\python nanodegree\\chicago.csv',
              'new_york_city': 'E:\\Data Analysis\\projects\\python nanodegree\\new_york_city.csv',
              'washington':    'E:\\Data Analysis\\projects\\python nanodegree\\washington.csv' }

# %%
def get_filters():
    """
    Asks user to specify a city, month, and day to analyze.

    Returns:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    """
    print('Hello! Let\'s explore some US bikeshare data!')
    # TO DO: get user input for city (chicago, new york city, washington). HINT: Use a while loop to handle invalid inputs
    cities=['chicago','new_york_city','washington']
    city=''
    while(True):
        city=input("Please Enter a valid city from {}".format(cities)).lower()
        if(city in cities):
            break


    # TO DO: get user input for month (all, january, february, ... , june)
    months=['january','february','march','april','may','june']
    month=''
    while(True):
        month=input("Please Enter a valid month from {} or all to apply no month filter ".format(months)).lower()
        if((month in months) or (month=='all')):
            break


    # TO DO: get user input for day of week (all, monday, tuesday, ... sunday)
    days=['monday','tuesday','wednesday','thursday','friday','saturday','sunday']
    day=''
    while(True):
        day=input("Please Enter a valid day from {} or all to apply no day filter ".format(days)).lower()
        if((day in days) or (day=='all')):
            break


    print('-'*40)
    return city, month, day

# %%
#x,y,z=get_filters()
# Out:
# Hello! Let's explore some US bikeshare data!
# Please Enter a valid city from ['chicago', 'new_york_city', 'washington']washington
# Please Enter a valid month from ['january', 'february', 'march', 'april', 'may', 'june'] or all to apply no month filter march
# Please Enter a valid day from ['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday'] or all to apply no day filter tuesday
# ----------------------------------------

# %%
def load_data(city, month, day):
    """
    Loads data for the specified city and filters by month and day if applicable.

    Args:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    Returns:
        df - Pandas DataFrame containing city data filtered by month and day
    """

    # load data file into a dataframe
    df = read_csv(CITY_DATA[city])

    # convert the Start Time column to datetime
    df['Start Time'] = to_datetime(df['Start Time'])
    df['hour']=df['Start Time'].dt.hour

    # extract month and day of week from Start Time to create new columns
    df['month'] = df['Start Time'].dt.month
    df['day_of_week'] = df['Start Time'].dt.day_name().str.lower()

    # filter by month if applicable
    if month != 'all':
        # use the index of the months list to get the corresponding int
        months = ['january', 'february', 'march', 'april', 'may', 'june']
        month = months.index(month) + 1

        # filter by month to create the new dataframe
        df = df[df['month'] == month]

    # filter by day of week if applicable
    if day != 'all':
        # filter by day of week to create the new dataframe
        df = df[df['day_of_week'] == day]

    return df

# %%
# print(x,y,z)
# df=load_data(x,y,z)
# print(df)

# %%
def time_stats(df): 
    """Displays statistics on the most frequent times of travel."""

    print('\nCalculating The Most Frequent Times of Travel...\n')
    start_time = time.time()

    # TO DO: display the most common month
    print("The most common month is :{}".format(df['month'].mode()[0]))


    # TO DO: display the most common day of week
    print("The most common day is :{}".format(df['day_of_week'].mode()[0]))


    # TO DO: display the most common start hour
    print("The most common hour is :{}".format(df['hour'].mode()[0]))


    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
# time_stats(df)
# print(df)
# Out:
# Calculating The Most Frequent Times of Travel...
#
# The most common month is :3
# The most common day is :tuesday
# The most common hour is :17
#
# This took 0.0030176639556884766 seconds.
# ----------------------------------------
#         Unnamed: 0          Start Time             End Time  Trip Duration  \
# 111         447561 2017-03-07 12:30:00  2017-03-07 12:39:00        556.591
# 124         545280 2017-03-21 17:35:00  2017-03-21 17:51:00        932.750
# 140         613828 2017-03-28 15:58:00  2017-03-28 16:11:00        787.804
# 272         447897 2017-03-07 13:15:00  2017-03-07 13:30:00        893.093
# 332         541331 2017-03-21 10:29:00  2017-03-21 10:40:00        683.660
# ...            ...                 ...                  ...            ...
# 299745      541493 2017-03-21 11:01:00  2017-03-21 11:13:00        715.934
# 299758      613314 2017-03-28 15:12:00  2017-03-28 15:31:00       1175.315
# 299882      545855 2017-03-21 17:59:00  2017-03-21 18:26:00       1637.243
# 299885      446856 2017-03-07 10:42:00  2017-03-07 10:57:00        888.257
# 299906      497997 2017-03-14 11:22:00  2017-03-14 11:38:00       1011.621
#
#                                             Start Station  \
# 111                                         4th & M St SW
# 124                                N Lynn St & Fairfax Dr
# 140                            14th & Rhode Island Ave NW
# 272                                        18th & M St NW
# 332                                        24th & N St NW
# ...                                                   ...
# 299745  Eastern Market Metro / Pennsylvania Ave & 7th ...
# 299758                                      1st & D St SE
# 299882   Ohio Dr & West Basin Dr SW / MLK & FDR Memorials
# 299885                      22nd & I St NW / Foggy Bottom
# 299906                            Park Rd & Holmead Pl NW
#
#                                           End Station   User Type  hour  \
# 111                                3rd & Tingey St SE  Subscriber    12
# 124     Clarendon Metro / Wilson Blvd & N Highland St  Subscriber    17
# 140                                    10th & G St NW  Subscriber    15
# 272            37th & O St NW / Georgetown University  Subscriber    13
# 332                        14th & Rhode Island Ave NW  Subscriber    10
# ...                                               ...         ...   ...
# 299745                                  5th & F St NW  Subscriber    11
# 299758                                  7th & T St NW  Subscriber    15
# 299882                 C & O Canal & Wisconsin Ave NW    Customer    17
# 299885                                 11th & F St NW  Subscriber    10
# 299906              Convention Center / 7th & M St NW  Subscriber    11
#
#         month day_of_week
# 111         3     tuesday
# 124         3     tuesday
# 140         3     tuesday
# 272         3     tuesday
# 332         3     tuesday
# ...       ...         ...
# 299745      3     tuesday
# 299758      3     tuesday
# 299882      3     tuesday
# 299885      3     tuesday
# 299906      3     tuesday
#
# [5348 rows x 10 columns]

# %%
def station_stats(df):
    """Displays statistics on the most popular stations and trip."""

    print('\nCalculating The Most Popular Stations and Trip...\n')
    start_time = time.time()

    # TO DO: display most commonly used start station
    print("most commonly used start station is ",df['Start Station'].mode()[0])


    # TO DO: display most commonly used end station
    print("most commonly used End station is ",df['End Station'].mode()[0])


    # TO DO: display most frequent combination of start station and end station trip
    print("most frequent combination of start station and end station trip is",intersect1d(df['Start Station'],df['End Station'].mode()[0]))


    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
 #station_stats(df)

# %%
def trip_duration_stats(df):
    """Displays statistics on the total and average trip duration."""

    print('\nCalculating Trip Duration...\n')
    start_time = time.time()

    # TO DO: display total travel time
    print(sum(df['Trip Duration']))


    # TO DO: display mean travel time
    print(mean(df['Trip Duration']))


    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
#trip_duration_stats(df)

# %%
def user_stats(df):
    """Displays statistics on bikeshare users."""

    print('\nCalculating User Stats...\n')
    start_time = time.time()

    # TO DO: Display counts of user types
    print("counts of user types:\n",df['User Type'].value_counts())


    # TO DO: Display counts of gender
    if('Gender' not in df):
        print("there is no gender type in this data fram")
    else:
        print("counts of gender:\n",df['Gender'].value_counts())


    # TO DO: Display earliest, most recent, and most common year of birth
    if('Birth Year' not in df):
        print("there is no Birth Year in this data fram")
    else:
        print("earliest, most recent, and most common year of birth are:")
        print(df['Birth Year'].min(),df['Birth Year'].max(),df['Birth Year'].mode()[0])


    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
#user_stats(df)

# %%
def Display_Data():
    view_data = input('\nWould you like to view 5 rows of individual trip data? Enter yes or no\n').lower()
    start_loc = 0
    while(view_data=='yes'):
        print(df.iloc[start_loc:start_loc+5])
        start_loc += 5
        view_data = input("Do you wish to continue?: Enter yes or no\n").lower()

# %%
def main():
    while True:
        city, month, day = get_filters()
        print(city,month,day)   
        df = load_data(city, month, day)
        
        time_stats(df)
        station_stats(df)
        trip_duration_stats(df)
        user_stats(df)
        Display_Data()

        restart = input('\nWould you like to restart? Enter yes or no.\n')
        if restart.lower() != 'yes':
            break

# %%
if __name__ == "__main__":
	main()
# Out:
# Hello! Let's explore some US bikeshare data!
# Please Enter a valid city from ['chicago', 'new_york_city', 'washington']washington
# Please Enter a valid month from ['january', 'february', 'march', 'april', 'may', 'june'] or all to apply no month filter may
# Please Enter a valid day from ['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday'] or all to apply no day filter tuesday
# ----------------------------------------
# washington may tuesday
#
# Calculating The Most Frequent Times of Travel...
#
# The most common month is :5
# The most common day is :tuesday
# The most common hour is :5
#
# This took 0.0 seconds.
# ----------------------------------------
#
# Calculating The Most Popular Stations and Trip...
#
# most commonly used start station is  Columbus Circle / Union Station
# most commonly used End station is  Columbus Circle / Union Station
# most frequent combination of start station and end station trip is ['Columbus Circle / Union Station']
#
# This took 0.015653133392333984 seconds.
# ----------------------------------------
#
# Calculating Trip Duration...
#
# 11144638.315
# 1088.024828175341
#
# This took 0.0 seconds.
# ----------------------------------------
#
# Calculating User Stats...
#
# counts of user types:
#  Subscriber    8174
# Customer      2069
# Name: User Type, dtype: int64
# there is no gender type in this data fram
# there is no Birth Year in this data fram
#
# This took 0.0 seconds.
# ----------------------------------------
#
# Would you like to view 5 rows of individual trip data? Enter yes or no
# yes
#      Unnamed: 0          Start Time             End Time  Trip Duration  \
# 111      447561 2017-03-07 12:30:00  2017-03-07 12:39:00        556.591
# 124      545280 2017-03-21 17:35:00  2017-03-21 17:51:00        932.750
# 140      613828 2017-03-28 15:58:00  2017-03-28 16:11:00        787.804
# 272      447897 2017-03-07 13:15:00  2017-03-07 13:30:00        893.093
# 332      541331 2017-03-21 10:29:00  2017-03-21 10:40:00        683.660
#
#                   Start Station  \
# 111               4th & M St SW
# 124      N Lynn St & Fairfax Dr
# 140  14th & Rhode Island Ave NW
# 272              18th & M St NW
# 332              24th & N St NW
#
#                                        End Station   User Type  hour  month  \
# 111                             3rd & Tingey St SE  Subscriber    12      3
# 124  Clarendon Metro / Wilson Blvd & N Highland St  Subscriber    17      3
# 140                                 10th & G St NW  Subscriber    15      3
# 272         37th & O St NW / Georgetown University  Subscriber    13      3
# 332                     14th & Rhode Island Ave NW  Subscriber    10      3
#
#     day_of_week
# 111     tuesday
# 124     tuesday
# 140     tuesday
# 272     tuesday
# 332     tuesday
# Do you wish to continue?: Enter yes or no
# yes
#      Unnamed: 0          Start Time             End Time  Trip Duration  \
# 381      542487 2017-03-21 13:44:00  2017-03-21 13:53:00        549.488
# 548      615554 2017-03-28 17:32:00  2017-03-28 17:45:00        740.424
# 650      544103 2017-03-21 16:39:00  2017-03-21 16:50:00        663.377
# 651      447430 2017-03-07 12:13:00  2017-03-07 12:27:00        872.711
# 754      447346 2017-03-07 12:00:00  2017-03-07 12:18:00       1031.922
#
#                   Start Station                     End Station   User Type  \
# 381          9th & Upshur St NW                   7th & T St NW  Subscriber
# 548             23rd & E St NW   17th St & Massachusetts Ave NW  Subscriber
# 650  Clarendon Blvd & Pierce St         Fairfax Dr & Kenmore St  Subscriber
# 651      N Quincy St & Glebe Rd      Clarendon Blvd & Pierce St  Subscriber
# 754               5th & F St NW             14th & Girard St NW  Subscriber
#
#      hour  month day_of_week
# 381    13      3     tuesday
# 548    17      3     tuesday
# 650    16      3     tuesday
# 651    12      3     tuesday
# 754    12      3     tuesday
# Do you wish to continue?: Enter yes or no
# yes
#      Unnamed: 0          Start Time             End Time  Trip Duration  \
# 794      615811 2017-03-28 17:41:00  2017-03-28 17:45:00        206.258
# 798      449184 2017-03-07 16:12:00  2017-03-07 16:21:00        551.461
# 817      449302 2017-03-07 16:24:00  2017-03-07 16:35:00        673.151
# 850      545106 2017-03-21 17:27:00  2017-03-21 17:34:00        398.389
# 920      617479 2017-03-28 18:51:00  2017-03-28 19:05:00        845.603
#
#                                          Start Station  \
# 794  Walter Reed Community Center / Walter Reed Dr ...
# 798                          New York Ave & 15th St NW
# 817                     Clarendon Blvd & N Fillmore St
# 850                     7th & F St NW/Portrait Gallery
# 920                     17th St & Massachusetts Ave NW
#
#                           End Station   User Type  hour  month day_of_week
# 794  Columbia Pike & S Walter Reed Dr    Customer    17      3     tuesday
# 798    L'Enfant Plaza / 7th & C St SW  Subscriber    16      3     tuesday
# 817      Arlington Blvd & Fillmore St  Subscriber    16      3     tuesday
# 850        North Capitol St & F St NW  Subscriber    17      3     tuesday
# 920        Rhode Island Ave & V St NE  Subscriber    18      3     tuesday
# Do you wish to continue?: Enter yes or no
# no
#
# Would you like to restart? Enter yes or no.
# no
